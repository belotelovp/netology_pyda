# %% [markdown]
# # Задание

# %% [markdown]
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма: strategy, maxiter, popsize, tol, mutation, recombination и updating.
#
# Постройте графики количества итераций оптимизации функции ackley от значения параметра.

# %% [markdown]
# Допзадание
#
# Найти множество параметров (strategy=..., maxiter=..., ..., updating=...), которые требуют минимального количества итераций.

# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]
result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2763
#      nit: 89
#  success: True
#        x: array([0., 0.])

# %% [markdown]
# 1) Strategy

# %%
x_strategy = ['best1bin', 'best1exp', 'rand1exp', 'randtobest1exp',
              'currenttobest1exp', 'best2exp', 'rand2exp', 'randtobest1bin',
              'currenttobest1bin', 'best2bin', 'rand2bin', 'rand1bin']

bounds = [(-10, 10), (-10, 10)]
y_strategy = []

for val in x_strategy:
    result = differential_evolution(ackley, bounds, seed=42, strategy=val)
    y_strategy.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_strategy, y_strategy)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 2) Maxiter

# %%
x_maxiter = [i for i in range(30)]

bounds = [(-10, 10), (-10, 10)]
y_maxiter = []

for val in x_maxiter:
    result = differential_evolution(ackley, bounds, seed=42, maxiter=val)
    y_maxiter.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_maxiter, y_maxiter)
plt.show()

# %% [markdown]
# 3) Popsize

# %%
x_popsize = [i for i in range(30)]

bounds = [(-10, 10), (-10, 10)]
y_popsize = []

for val in x_popsize:
    result = differential_evolution(ackley, bounds, seed=42, popsize=val)
    y_popsize.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_popsize, y_popsize)
plt.show()

# %% [markdown]
# 4) Tol

# %%
x_tol = np.linspace(0, 1, 100)

bounds = [(-10, 10), (-10, 10)]
y_tol = []

for val in x_tol:
    result = differential_evolution(ackley, bounds, seed=42, tol=val)
    y_tol.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_tol, y_tol)
plt.show()

# %% [markdown]
# 5) Mutation

# %%
x_mutation = np.linspace(0, 1.99, 100)

bounds = [(-10, 10), (-10, 10)]
y_mutation = []

for val in x_mutation:
    result = differential_evolution(ackley, bounds, seed=42, mutation=val)
    y_mutation.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_mutation, y_mutation)
plt.show()

# %% [markdown]
# 6) Recombination

# %%
x_recombination = np.linspace(0, 1, 100)

bounds = [(-10, 10), (-10, 10)]
y_recombination = []

for val in x_recombination:
    result = differential_evolution(ackley, bounds, seed=42, recombination=val)
    y_recombination.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_recombination, y_recombination)
plt.show()

# %% [markdown]
# 7) Updating

# %%
x_updating = ['immediate', 'deferred']

bounds = [(-10, 10), (-10, 10)]
y_updating = []

for val in x_updating:
    result = differential_evolution(ackley, bounds, seed=42, updating=val)
    y_updating.append(result.nit)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_updating, y_updating)
plt.show()
